# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/umeehani802/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# # This cell is for CODE (numbers, a query, a check).
# # Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# ## My Lane: Refresh / Content Opportunity Scoring
#
# I selected the **Refresh / Content Opportunity Scoring** lane because it focuses on identifying
#  which content pages should be reviewed first using search and engagement signals. This project has
#  practical business value because it helps content teams prioritize their limited time on pages that are most likely to benefit from review.
#  The starter dataset supports this lane well, and it provides a good foundation for developing and improving a ranking model over the next seven weeks.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# # This cell is for CODE (numbers, a query, a check).
# # Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# ## Research Question
#
# Which content pages should be prioritized for review based on their likelihood of declining performance?
#
# ### Decision
# The project helps content teams decide which pages should be reviewed first.
#
# ### Unit of Analysis
# One content page.
#
# ### Output
# A ranked refresh score or predicted decline risk for each page.
#
# ### Action
# The content team can review, update, expand, or monitor the highest-ranked pages first.
#
# ### Cost of a Wrong Recommendation
# If the recommendation is wrong, valuable pages may be ignored while time is spent reviewing pages that do not need attention. This can reduce the effectiveness of content improvement efforts.
#
# ### Why Data and Machine Learning Help
# The dataset contains many search and engagement signals that are difficult to evaluate manually. Machine learning can combine these signals to rank pages more effectively and support better decision-making.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# # This cell is for CODE (numbers, a query, a check).
# # Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# The following code loads the starter dataset and reports a few basic statistics to understand the data and support the selected project lane.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

# Load the starter dataset
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# Display 2–3 real numbers
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
print("Average 90-day impressions:", round(df["impressions_90d"].mean(), 2))
print("Declining pages:", (df["trend_direction"] == "down").sum())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_307/3037537368.py in <cell line: 0>()
#       4
#       5 # Load the starter dataset
# ----> 6 df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
#       7
#       8 # Display 2–3 real numbers
#
# ...

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
